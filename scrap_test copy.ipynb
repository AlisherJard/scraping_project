# %%
# Locality
# Type of property (House/apartment)
# Subtype of property (Bungalow, Chalet, Mansion, ...)
# Price
# Type of sale (Exclusion of life sales)
# Number of rooms
# Living Area (m²)
# Fully equipped kitchen (Yes/No)
# Furnished (Yes/No)
# Open fire (Yes/No)
# Terrace (Yes/No)
# If yes: Area (m²)
# Garden (Yes/No)
# If yes: Area (m²)
# Surface of the plot (m²)
# Number of facades
# Swimming pool (Yes/No)
# State of the building (New, to be renovated, ...)

# %%
def scrape(url):
    ''''scrapes data from url'''
    text = requests.get(f"{url}",headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
    soup = BeautifulSoup(text.text,'html')
    return soup.prettify()

page_1 = scrape("https://www.immoweb.be/en/search/house/for-sale?countries=BE&page=1&orderBy=relevance")

def find_links(page_num):
    ''''finds links of all <a> tags with class "card__title-link, and returns the href attribute of each found element'''
    
    href = []
    soup = BeautifulSoup(page_num, 'html.parser')

    links = soup.find_all('a', class_='card__title-link')

    for link in links:
        href.append(link['href'])
    
    return href

    
print(find_links(page_1))

# %%
def scrape(url):
    '''Scrapes data from url'''
    response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

def find_links(soup):
    '''Finds links of all <a> tags with class "card__title-link" and returns the href attribute of each found element'''
    hrefs = []
    links = soup.find_all('a', class_='card__title-link')
    for link in links:
        hrefs.append(link['href'])
    return hrefs

def scrape_multiple_pages(base_url, total_pages):
    '''Scrapes multiple pages and collects all the links'''
    all_links = []
    for page_num in range(1, total_pages + 1):
        url = f"{base_url}&page={page_num}"
        soup = scrape(url)
        page_links = find_links(soup)
        all_links.extend(page_links)
    return all_links

buy=[]
base_url = "https://www.immoweb.be/en/search/house-and-apartment/for-sale?countries=BE&priceType=SALE_PRICE&page=1&orderBy=relevance"
total_pages = 333

all_links = scrape_multiple_pages(base_url, total_pages)

for link in all_links:
    buy.append(link)


buy_set = set(buy)
print(buy_set)
print(len(buy_set))
# Out:
# {'https://www.immoweb.be/en/classified/house/for-sale/li%C3%A8ge%202/4020/11285837', 'https://www.immoweb.be/en/classified/house/for-sale/uccle/1180/11405206', 'https://www.immoweb.be/en/classified/apartment/for-sale/la-louviere/7100/11483361', 'https://www.immoweb.be/en/classified/apartment/for-sale/neufchateau-hamipre/6840/11472892', 'https://www.immoweb.be/en/classified/apartment/for-sale/uccle/1180/11293152', 'https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/11361978', 'https://www.immoweb.be/en/classified/apartment/for-sale/saint-josse-ten-noode/1210/11482324', 'https://www.immoweb.be/en/classified/apartment/for-sale/bilzen/3740/11474792', 'https://www.immoweb.be/en/classified/house/for-sale/haccourt/4684/11429644', 'https://www.immoweb.be/en/classified/house/for-sale/brasschaat/2930/11474963', 'https://www.immoweb.be/en/classified/apartment/for-sale/brasschaat/2930/11377863', 'https://www.immoweb.be/en/classified/house/for-sale/verviers/4800/11462831', 'https://www.immoweb.be/en/classified/house/for-sale/antwerpen/2060/11422000', 'https://www.immoweb.be/en/classified/house/for-sale/grez-doiceau/1390/11463286', 'https://www.immoweb.be/en/classified/apartment/for-sale/sint-niklaas/9100/20002419', 'https://www.immoweb.be/en/classified/villa/for-sale/hove/2540/11462656', 'https://www.immoweb.be/en/classified/house/for-sale/stoumont/4987/11484876', 'https://www.immoweb.be/en/classified/house/for-sale/melsele%20%28beveren%29/9120/11480435', 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale